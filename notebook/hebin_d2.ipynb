# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\user\OneDrive\Desktop\5thsem_ojt\project1_diabetes\data\processed\project1_diabetes_clean.csv',parse_dates=['last_checkup_date'])

# %%
df.head(10)
# Out:
#   patient_id  age  gender  pregnancies  glucose  blood_pressure  \
# 0     P00826   79    male            0    124.0            71.0
# 1     P00108   37    male            0    153.0            85.0
# 2     P00517   39  female            0    142.0            68.0
# 3     P00687   68  female            7    121.0            88.0
# 4     P00927   75  female            0    107.0            84.0
# 5     P00755   37  female            0    145.0            80.0
# 6     P00431   58    male            5     95.0            72.0
# 7     P00542   58  female            3    150.0            68.0
# 8     P00929   32  female            6    129.0            74.0
# 9     P00513   61  female            0    161.0            77.0
#
#    skin_thickness  insulin   bmi  diabetes_pedigree physical_activity  \
# 0            30.0    124.0  23.4              0.588           Unknown
# 1            24.0     42.0  33.9              0.192            Medium
# 2            22.0    159.0  26.9              0.777               Low
# 3            26.0    124.0  29.0              1.217           Unknown
# 4            31.0    101.0  21.2              0.278               Low
# 5            26.0    124.0  22.0              0.488              High
# 6            26.0    170.0  27.2              0.197              High
# 7            17.0    124.0  46.0              0.808            Medium
# 8            26.0    226.0  20.6              0.655              High
# 9            35.0    201.0  35.0              1.229            Medium
#
#     smoker last_checkup_date  outcome
# 0       NO        2023-04-20        0
# 1      YES        2024-05-03        1
# 2  UNKNOWN        2023-07-08        0
# 3      YES        2024-04-14        1
# 4       NO        2024-01-27        0
# 5      YES        2024-01-10        0
# 6       NO        2023-12-25        0
# 7       NO        2024-06-20        1
# 8  UNKNOWN        2023-10-15        1
# 9      YES        2023-12-22        1

# %%
df.dtypes
# Out:
# patient_id                      str
# age                           int64
# gender                          str
# pregnancies                   int64
# glucose                     float64
# blood_pressure              float64
# skin_thickness              float64
# insulin                     float64
# bmi                         float64
# diabetes_pedigree           float64
# physical_activity               str
# smoker                          str
# last_checkup_date    datetime64[us]
# outcome                       int64
# dtype: object

# %% [markdown]
# Create an age-band features

# %%
df['age_band']=pd.cut(df['age'],bins=[0,35,55,120],labels=('0-35','35-55','over-55'))

# %%
df.head(10)
# Out:
#   patient_id  age  gender  pregnancies  glucose  blood_pressure  \
# 0     P00826   79    male            0    124.0            71.0
# 1     P00108   37    male            0    153.0            85.0
# 2     P00517   39  female            0    142.0            68.0
# 3     P00687   68  female            7    121.0            88.0
# 4     P00927   75  female            0    107.0            84.0
# 5     P00755   37  female            0    145.0            80.0
# 6     P00431   58    male            5     95.0            72.0
# 7     P00542   58  female            3    150.0            68.0
# 8     P00929   32  female            6    129.0            74.0
# 9     P00513   61  female            0    161.0            77.0
#
#    skin_thickness  insulin   bmi  diabetes_pedigree physical_activity  \
# 0            30.0    124.0  23.4              0.588           Unknown
# 1            24.0     42.0  33.9              0.192            Medium
# 2            22.0    159.0  26.9              0.777               Low
# 3            26.0    124.0  29.0              1.217           Unknown
# 4            31.0    101.0  21.2              0.278               Low
# 5            26.0    124.0  22.0              0.488              High
# 6            26.0    170.0  27.2              0.197              High
# 7            17.0    124.0  46.0              0.808            Medium
# 8            26.0    226.0  20.6              0.655              High
# 9            35.0    201.0  35.0              1.229            Medium
#
#     smoker last_checkup_date  outcome age_band
# 0       NO        2023-04-20        0  over-55
# 1      YES        2024-05-03        1    35-55
# 2  UNKNOWN        2023-07-08        0    35-55
# 3      YES        2024-04-14        1  over-55
# 4       NO        2024-01-27        0  over-55
# 5      YES        2024-01-10        0    35-55
# 6       NO        2023-12-25        0  over-55
# 7       NO        2024-06-20        1  over-55
# 8  UNKNOWN        2023-10-15        1     0-35
# 9      YES        2023-12-22        1  over-55

# %% [markdown]
# Create a BMI category features

# %%
df['bmi_category']=pd.cut(df['bmi'],bins=[0,18.5,25,30,100],labels=('underweight','normal','overweight','obese'))

# %%
df['bmi_category'].value_counts()
# Out:
# bmi_category
# obese          553
# overweight     235
# normal         124
# underweight     38
# Name: count, dtype: int64

# %% [markdown]
# Create a glucose band features

# %%
df['glucose_band']=pd.cut(df['glucose'],bins=[0,100,126,300],labels=('normal','prediabetic','diabetic'))

# %%
df['glucose_band'].value_counts()
# Out:
# glucose_band
# diabetic       349
# prediabetic    337
# normal         264
# Name: count, dtype: int64

# %% [markdown]
# Create an insulin to glucose ratio feature

# %%
df['insulin_glucose_ratio']=df['insulin']/df['glucose']

# %%
df['insulin_glucose_ratio'].value_counts()
# Out:
# insulin_glucose_ratio
# 0.953846    9
# 1.052139    7
# 1.078261    7
# 0.898551    6
# 1.033333    6
#            ..
# 2.163121    1
# 0.101010    1
# 0.885714    1
# 1.984615    1
# 1.536585    1
# Name: count, Length: 743, dtype: int64

# %%
df.head(10)
# Out:
#   patient_id  age  gender  pregnancies  glucose  blood_pressure  \
# 0     P00826   79    male            0    124.0            71.0
# 1     P00108   37    male            0    153.0            85.0
# 2     P00517   39  female            0    142.0            68.0
# 3     P00687   68  female            7    121.0            88.0
# 4     P00927   75  female            0    107.0            84.0
# 5     P00755   37  female            0    145.0            80.0
# 6     P00431   58    male            5     95.0            72.0
# 7     P00542   58  female            3    150.0            68.0
# 8     P00929   32  female            6    129.0            74.0
# 9     P00513   61  female            0    161.0            77.0
#
#    skin_thickness  insulin   bmi  diabetes_pedigree physical_activity  \
# 0            30.0    124.0  23.4              0.588           Unknown
# 1            24.0     42.0  33.9              0.192            Medium
# 2            22.0    159.0  26.9              0.777               Low
# 3            26.0    124.0  29.0              1.217           Unknown
# 4            31.0    101.0  21.2              0.278               Low
# 5            26.0    124.0  22.0              0.488              High
# 6            26.0    170.0  27.2              0.197              High
# 7            17.0    124.0  46.0              0.808            Medium
# 8            26.0    226.0  20.6              0.655              High
# 9            35.0    201.0  35.0              1.229            Medium
#
#     smoker last_checkup_date  outcome age_band bmi_category glucose_band  \
# 0       NO        2023-04-20        0  over-55       normal  prediabetic
# 1      YES        2024-05-03        1    35-55        obese     diabetic
# 2  UNKNOWN        2023-07-08        0    35-55   overweight     diabetic
# 3      YES        2024-04-14        1  over-55   overweight  prediabetic
# 4       NO        2024-01-27        0  over-55       normal  prediabetic
# 5      YES        2024-01-10        0    35-55       normal     diabetic
# 6       NO        2023-12-25        0  over-55   overweight       normal
# 7       NO        2024-06-20        1  over-55        obese     diabetic
# 8  UNKNOWN        2023-10-15        1     0-35       normal     diabetic
# 9      YES        2023-12-22        1  over-55        obese     diabetic
#
#    insulin_glucose_ratio
# 0               1.000000
# 1               0.274510
# 2               1.119718
# 3               1.024793
# 4               0.943925
# 5               0.855172
# 6               1.789474
# 7               0.826667
# 8               1.751938
# 9               1.248447

# %% [markdown]
# Check the ratio for impossible value

# %%
df['insulin_glucose_ratio'].describe()
# Out:
# count    950.000000
# mean       1.213108
# std        1.179183
# min        0.054348
# 25%        0.726708
# 50%        1.052139
# 75%        1.512831
# max       22.745763
# Name: insulin_glucose_ratio, dtype: float64

# %%
import numpy as np

# %%
np.isinf(df['insulin_glucose_ratio']).sum()
# Out:
# np.int64(0)

# %% [markdown]
# Create a pregnancies-per-year-of-age feature

# %%
df['pregnancies_age_ratio']=df['pregnancies']/df['age']

# %%
df['pregnancies_age_ratio'].describe()
# Out:
# count    950.000000
# mean       0.042787
# std        0.067440
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.072661
# max        0.380952
# Name: pregnancies_age_ratio, dtype: float64

# %% [markdown]
# Create a days-since-last-checkup features

# %%
reference_date=df['last_checkup_date'].max()

# %%
reference_date
# Out:
# Timestamp('2024-12-28 00:00:00')

# %%
df['days_since_checkup']=(reference_date-df['last_checkup_date']).dt.days

# %%
df['days_since_checkup'].head(10)
# Out:
# 0    618
# 1    239
# 2    539
# 3    258
# 4    336
# 5    353
# 6    369
# 7    191
# 8    440
# 9    372
# Name: days_since_checkup, dtype: int64

# %% [markdown]
# Create a categorical combination  feature

# %%
df['activity_smoker']=df['physical_activity']+'/'+df['smoker']

# %% [markdown]
# Check the combination features balance

# %%
df['activity_smoker'].value_counts()
# Out:
# activity_smoker
# Medium/NO          207
# High/NO            195
# Low/NO             180
# Low/YES             93
# Medium/YES          90
# High/YES            85
# Unknown/NO          36
# High/UNKNOWN        22
# Unknown/YES         17
# Medium/UNKNOWN      12
# Low/UNKNOWN          9
# Unknown/UNKNOWN      4
# Name: count, dtype: int64

# %% [markdown]
# Inventory every new column

# %%
# activity_smoker = physical activity + smoker
# days_since-checkup = reference - last-checkup_date
# pregnancies_age_ratio = pregnency/age
# insulin_glucose_ratio = insulin\glucose
# glucose_band = glucose
# bmi_category = bmi
# age_band = age

# %%
df.shape
# Out:
# (950, 21)
